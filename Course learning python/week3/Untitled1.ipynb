# %%
with open('file_one.csv', 'r') as temp:
    file_one = temp.readlines()
with open('file_two.csv', 'r') as temp:
    file_two = temp.readlines()
with open('file_three.csv', 'w') as temp:
    i = 0
    temp_new = ''
    temp_one = file_one[0]
    temp_two = file_two[0]
    length_one = len(temp_one)
    length_two = len(temp_two)
    temp_one = temp_one.strip()
    while i < length_two:
        if (temp_two[i] not in temp_one) and not (i + 1) == length_two:
            temp_one += ',' + temp_two[i]
            temp_new += ',' + temp_two[i]
        i += 1
    temp_one += '\n'
    temp.write(temp_one)
    temp_one = temp_one.split(',')
    length_line = len(temp_one)
file_one = file_one[1:]
length_file_one = len(file_one)
i = 0
with open('file_three.csv', 'a+') as temp:
    while length_file_one:
        new = file_one[i]
        if length_file_one - 1 == 0:
            new = new.strip()
            new += ',6,8\n'
        temp.write(new)
        i += 1
        length_file_one -= 1
i = 0
file_two = file_two[2:]
leng_two = len(file_two)
with open('file_three.csv', 'a+') as temp:
    while leng_two:
        new = file_two[i]
        temp_temp = new[0] + new[1] + new[2] + ',' + ',' + ',' + new[3] + new[4] + new[5] + new[6] + '\n'
        temp.write(temp_temp)
        leng_two -= 1
        i += 1

# %%
# Upload 52
with open('file_one.csv', 'r') as temp:
    file_one = temp.readlines()
with open('file_two.csv', 'r') as temp:
    file_two = temp.readlines()
with open('file_three.csv', 'w') as temp:
    i = 0
    temp_new = ''
    temp_one = file_one[0]
    temp_two = file_two[0]
    length_one = len(temp_one)
    length_two = len(temp_two)
    temp_one = temp_one.strip()
    while i < length_two:
        if (temp_two[i] not in temp_one) and not (i + 1) == length_two:
            temp_one += ',' + temp_two[i]
            temp_new += ',' + temp_two[i]
        i += 1
    temp_one += '\n'
    temp.write(temp_one)
    temp_one = temp_one.strip()
    temp_one = temp_one.split(',')
    length_line = len(temp_one)
i = 0
length_file_one = len(file_one)
list_of_lists_file_one = []
while length_file_one:
    temp_file_one = file_one[i]
    temp_file_one = temp_file_one.strip()
    temp_file_one = temp_file_one.split(',')
    list_of_lists_file_one.append(temp_file_one)
    i += 1
    length_file_one -= 1
i = 0
length_file_two = len(file_two)
list_of_lists_file_two = []
while length_file_two:
    temp_file_two = file_two[i]
    temp_file_two = temp_file_two.strip()
    temp_file_two = temp_file_two.split(',')
    list_of_lists_file_two.append(temp_file_two)
    i += 1
    length_file_two -= 1
flag = 1
i = 1
j = 0
k = 0
m = 0
zero = 0
length_list_of_list_one = len(list_of_lists_file_one)
length_list_of_list_two = len(list_of_lists_file_one)
while i < length_list_of_list_one:
    temp = list_of_lists_file_one[i][zero]
    while k < length_list_of_list_two:
        if temp == list_of_lists_file_two[k][zero]:
            flag = 0
        k += 1
    if flag:
        with open('file_three.csv', 'a+') as temp:
            temp.write(file_one[j + 1])
    else:
        with open('file_three.csv', 'a+') as temp:
            temp_new = file_two[i - 1]
            temp_new = temp_new.strip()
            temp_new = temp_new.split(',')
            length_temp_new = len(temp_new)
            new_new = file_one[j + 1]
            new_new = new_new.strip()
            while length_temp_new:
                if temp_new[m] != new_new[m] and temp_new[m] != '7':
                    new_new += ',' + temp_new[m]
                length_temp_new -= 1
                m += 1
            new_new += '\n'
            temp.write(new_new)
    k = 0
    i += 1
    j += 1
i = 0
file_two = file_two[2:]
leng_two = len(file_two)
with open('file_three.csv', 'a+') as temp:
    while leng_two:
        new = file_two[i]
        temp_temp = new[0] + new[1] + new[2] + ',' + ',' + ',' + new[3] + new[4] + new[5] + new[6] + '\n'
        temp.write(temp_temp)
        leng_two -= 1
        i += 1

# %%
def is_winner_in_coulmn(board):
    i = 0
    j = 0
    counter_x = 0
    counter_o = 0
    length_board = len(board)
    while length_board:
        temp = len(board)
        while temp:
            coulmn = board[i][j]
            if 'X' == coulmn:
                counter_x = counter_x + 1
            if 'O' == coulmn:
                counter_o = counter_o + 1
            i = i + 1
            temp = temp - 1
        i = 0
        j = j + 1
        length_board = length_board - 1
        if (counter_x == 3):
            return 'X'
        elif (counter_o == 3):
            return 'O'
        else:
            counter_x = 0
            counter_o = 0
    return False

tic_tac_toe([['-', '-', '-'], ['-', '-', '-'], ['-', '-', '-']])
